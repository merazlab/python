# %% [markdown]
# [matplotlib credit to](https://github.com/story645/mpl_tutorial)

# %% [markdown]
# ## Import libraries and check versions

# %%
import matplotlib
print(f'Matplotlib: {matplotlib.__version__}')
import matplotlib.pyplot as plt # load in matplotlib plotting tools
import pandas as pd # rename as pd by convention
print(f"pandas: {pd.__version__}")
import numpy as np  # rename as np by convention
print(f"numpy: {np.__version__}")
# Out:
# Matplotlib: 3.2.1
# pandas: 0.25.3
# numpy: 1.18.2

# %%
df = pd.read_csv("http://bit.ly/tcsv19")

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
# %matplotlib inline
fig, ax = plt.subplots()
_ = ax.plot(np.sort(df['age']), marker='o', markersize=1)

# %%
ax.plot? #show help

# %% [markdown]
# #Overview matplotlib

# %% [markdown]
# ![Diagram of the components of the matplotlib generated visualization.](https://github.com/story645/mpl_tutorial/blob/master/images/mpl_anatomy.png?raw=true)

# %%
import matplotlib
matplotlib.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure()

# %%
plt.subplots()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f4575d97f98>)

# %%
fig, ax = plt.subplots()

# %% [markdown]
# ## Adjusting figure size
# We can make the figure bigger or smaller using the `figsize=(width, height)` keyword construction. The default is 8x6

# %%
fig, ax = plt.subplots(figsize=(4,2))
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 59

# %%
import pandas as pd
df = pd.read_csv("http://bit.ly/tcsv19")

# %%
fig, ax = plt.subplots()
_ = ax.set_title ("Titanic Data Set")
_ = ax.plot(np.sort(df['age']), marker='o', markersize=1)
_ = ax.set_ylabel("Ages")
