# %% [markdown]
# #Module-06
# **Python Module**

# %%
# !pwd
# Out:
# /content

# %%
cd /content/drive/My Drive/python_basic/mod_06_filehandling_import
# Out:
# /content/drive/My Drive/python_basic/mod_06_filehandling_import

# %%
# !pwd
# Out:
# /content/drive/My Drive/python_basic/mod_06_filehandling_import

# %%
# !touch mod1.py

# %%
# !touch mod2.py

# %%
# !python3 mod2.py
# Out:
# 6
# module-2 is imported
# None

# %%
# !touch mod3.py

# %%
# !python3 mod3.py
# Out:
# 5
# module-1 is imported
# None
# 6
# module-2 is imported
# None

# %%
# !touch mod4.py

# %%
# !python3 mod4.py
# Out:
# 6
# module-2 is imported
# None

# %%
# !mkdir spack

# %%
cd spack/
# Out:
# /content/drive/My Drive/python_basic/mod_06_filehandling_import/spack

# %%
# !touch mod6.py

# %%
# !touch mod7.py

# %%
cd ..
# Out:
# /content/drive/My Drive/python_basic/mod_06_filehandling_import

# %%
# !touch main.py

# %%
# !python3 main.py
# Out:
# 5
# module-1 is imported
# None
# 9
# module-6 is imported
# None
# -------------------
# 6
# 7
# module-7 is imported
# None
