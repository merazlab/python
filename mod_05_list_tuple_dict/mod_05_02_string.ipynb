# %% [markdown]
# #String

# %% [markdown]
# Basic operation

# %%
name = "meraz"
var = "jai hind"
print(type(name))
# Out:
# <class 'str'>

# %%
print(name + var)
# Out:
# merazjai hind

# %%
print(var*3)
# Out:
# jai hindjai hindjai hind

# %%
print(name[1])
# Out:
# e

# %%
print(var[4:-1])
# Out:
# hin

# %%
print(var[4:])
# Out:
# hind

# %%
print("z" in name)
# Out:
# True

# %%
print("hind" in var)
# Out:
# True

# %% [markdown]
# ##String built-in function

# %% [markdown]
# https://www.javatpoint.com/python-strings

# %%
name = "meraz"
var = "jai hind"

# %%
print(name.capitalize())
# Out:
# Meraz

# %%
print(name.casefold()) #return lower case string
# Out:
# meraz

# %%
print(name)
print(var.center(20))
print(var.center(30,'#'))
# Out:
# meraz
#       jai hind
# ###########jai hind###########

# %%
print(var.count("i")) #no of i
# Out:
# 2

# %%
print(var.encode("utf-8"))
# Out:
# b'jai hind'

# %%
print(var.endswith(" ")) #check string ends
print(var.endswith("d"))
# Out:
# False
# True

# %%
var3 = "i \t am\t meraz"
print(var3.expandtabs())
# Out:
# i        am      meraz

# %%
var = "jai hind"
print(var.find("md")) #output -1 means, element not mount
print(var.find("hind")) #return index
# Out:
# -1
# 4

# %%
print("My name is:{} and my var: {}".format(name, var))
# Out:
# My name is:meraz and my var: jai hind

# %%
print(var.index("i"))
# Out:
# 2

# %%
print(var.isalnum())
print(name.isalnum())
# Out:
# False
# True

# %%
print(var.isalpha())
# Out:
# False

# %%
print(var.isdecimal())
# Out:
# False

# %%
print(var.isdigit())
# Out:
# False

# %%
var4 = "int"
print(var4.isidentifier())
# Out:
# True

# %%
print(var.islower())
# Out:
# True

# %%
print(var.isnumeric())
# Out:
# False

# %%
evar="meraz\n"
print(var.isprintable())
print(evar.isprintable())
# Out:
# True
# False

# %%
print(var.isupper())
# Out:
# False

# %%
print(var.istitle())
# Out:
# False

# %%
print(var.isspace())
# Out:
# False

# %%
str = ":"
list = ["2", "4", "6"]
print(str.join(list))
# Out:
# 2:4:6

# %%
#print(var.len())
print(len(list))
# Out:
# 3

# %%
print(var.ljust(15, "#"))
# Out:
# jai hind#######

# %%
print(var.lower())
# Out:
# jai hind

# %%
print(var.lstrip())
# Out:
# jai hind
